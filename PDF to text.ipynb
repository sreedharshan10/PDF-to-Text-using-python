# %%
#Using python to extract text from pdf using libraries

# %%
import PyPDF2

# %%
# Open the PDF file in binary mode
pdf = open("Sreeee.pdf", "rb")

# Create a PdfFileReader object from the binary file object
reader = PyPDF2.PdfReader(pdf)

# Get the first page of the PDF
page = reader.pages[0]

# Extract the text from the page using the extractText() method
text = page.extract_text()

# Print the extracted text
print(text)

# Close the PDF file
pdf.close()
# Out:
# P a
# 2
# -
# C o m p e t i t i v e
# A u d i t
# R e p o
# G o o g l e
# U X
# D e s i g n
# C e  i  c a t e
# 1 .
# C o m p e t i t i v e
# a u d i t
# g o a l ( s )
# C o m p a r i n g
# t h e
# t i c k e t
# b o o k i n g
# e x p e r i e n c e
# o f
# e a c h
# c o m p e t i t o r ' s
# a p p
# 2 .
# W h o
# a r e
# y o u r
# k e y
# c o m p e t i t o r s ?
# ( D e s c r i p t i o n )
# S o m e
# o f
# t h e
# m a j o r
# c o m p e t i t o r s
# i n c l u d e
# t i c k e t n e w ,
# b o o k m y s h o w ,
# p a y t m
# i n s i d e r
# a n d
# b o o k
# n o w .
# T h e s e
# a r e
# s o m e
# o f
# t h e
# l e a d i n g
# p l a  o r m s
# i n
# b o o k i n g
# t i c k e t s
# o n l i n e
# a n d
# h a v e
# t h e i r
# o w n
# r e p u t a t i o n .
# 3 .
# W h a t
# a r e
# t h e
# t y p e
# a n d
# q u a l i t y
# o f
# c o m p e t i t o r s ’
# p r o d u c t s ?
# ( D e s c r i p t i o n )
# T i c k e t
# n e w
# i s
# b a s i c a l l y
# a
# m i n i m a l i s t i c
# ...

# %%
#you can extract text from whichever page you like using the extract pages command
